# %% [markdown]
# **Ejercicio 2: Teoría de Errores**

# %% [markdown]
# C: 𝑓(𝑥)=√1+𝑥, centrado en 𝑥=0

# %% [markdown]
# Realice un programa en Python empleando el Jupyter Notebook que:
#
# •	Determine los polinomios de Taylor desde el grado cero (0) hasta el grado cinco (5).
#
# •	Realice una gráfica comparativa con la evaluación de los polinomios solicitados en el numeral anterior y determine cuál es el error de truncamiento resultante en cada uno de los polinomios hallados. Haga una gráfica del comportamiento del error para cada polinomio.
#
# •	Haga un análisis de resultados basándose en la teoría y en los resultados obtenidos. Debe incluir referencias a la bibliografía empleada usando las normas APA. Comentarios sin referencias no serán tenidos en cuenta.

# %%
import math
import matplotlib.pyplot as plt

data = []

for i in range(0, 5):
    data.append(math.sqrt(i+0))

plt.plot(data)
plt.ylabel('Valores en Y')
plt.xlabel('Valores en X')
plt.show()

# %% [markdown]
# En este ejercicio se tomó la formula y la constante que está allí
#
# 𝑓(𝑥)=√1+𝑥, centrado en 𝑥=0
#
# Por lo cual se determinaron los polinomios de Taylor desde el grado cero (0) hasta el grado cinco (5), realizando un ciclo de cero (0) a cinco (5), con lo cual se fue realizando a operación aritmética por lo valores dados
#
# Posteriormente se realizó una gráfica comparativa con la evaluación de los polinomios solicitados en el numeral anterior determinando cuál es el error de truncamiento resultante en cada uno de los polinomios hallados.
